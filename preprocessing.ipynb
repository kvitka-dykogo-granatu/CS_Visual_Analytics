# %% [markdown]
# Importing the data

# %%
from pathlib import Path
import json
import pandas as pd
import requests
import time
from typing import Dict, Optional
from datetime import datetime

INPUT_GLOB = "data/*.json"
OG_CSV = "data/og_data.csv"
CLEANED_CSV = "data/cleaned_data.csv"
ENRICHED_CSV = "data/music_data.csv"

# %% [markdown]
# The data I obtained from spotify was in 4 json files of the same structure, so I extract it and after preprocessing I'll produce a csv file

# %%
from glob import glob

files = sorted(glob(INPUT_GLOB))
if not files:
    raise FileNotFoundError(f"No files matched {INPUT_GLOB}")

frames = []
for fp in files:
    with open(fp, "r", encoding="utf-8") as f:
        data = json.load(f)
        if not isinstance(data, list):
            print(f"Skipping {fp}: top-level JSON is not a list")
            continue
        df = pd.json_normalize(data)
        frames.append(df)

merged = pd.concat(frames, ignore_index=True) if frames else pd.DataFrame()
print(f"Loaded {len(files)} files → {len(merged):,} rows × {merged.shape[1]} cols")
merged.tail()
# Out:
# Loaded 4 files → 58,319 rows × 23 cols
#                          ts platform  ms_played conn_country       ip_addr  \
# 58314  2025-10-10T21:40:06Z  android     215813           FR  193.52.24.53
# 58315  2025-10-10T21:43:10Z  android     184013           FR  193.52.24.53
# 58316  2025-10-10T21:47:45Z  android     273765           FR  193.52.24.53
# 58317  2025-10-10T21:51:27Z  android     221273           FR  193.52.24.53
# 58318  2025-10-10T21:53:46Z  android     139384           FR  193.52.24.53
#
#       master_metadata_track_name master_metadata_album_artist_name  \
# 58314              Gonna Love Ya                            Avicii
# 58315                   Chemical                       Post Malone
# 58316      Virus (How About Now)                     Martin Garrix
# 58317        Reload - Radio Edit                Sebastian Ingrosso
# 58318   Gatluak - Bakermat Remix                            Kronan
#
#       master_metadata_album_album_name                     spotify_track_uri  \
# 58314                          Stories  spotify:track:1rDETmcizen79JghAEm1Se
# 58315                         Chemical  spotify:track:5w40ZYhbBMAlHYNDaVJIUu
# 58316            Virus (How About Now)  spotify:track:3ukWpmRHvpuDATCJkgLEkF
# 58317                           Reload  spotify:track:5jyUBKpmaH670zrXrE0wmO
# 58318                          Gatluak  spotify:track:0GT2hQQ6mdHeW0AZDl5NlJ
#
#       episode_name  ... audiobook_uri audiobook_chapter_uri  \
# 58314         None  ...          None                  None
# 58315         None  ...          None                  None
# 58316         None  ...          None                  None
# 58317         None  ...          None                  None
# 58318         None  ...          None                  None
#
#       audiobook_chapter_title reason_start reason_end shuffle skipped offline  \
# 58314                    None    trackdone  trackdone    True   False   False
# 58315                    None    trackdone  trackdone    True   False   False
# 58316                    None    trackdone  trackdone    True   False   False
# 58317                    None    trackdone  trackdone    True   False   False
# 58318                    None    trackdone  trackdone    True   False   False
#
#        offline_timestamp  incognito_mode
# 58314       1.760132e+09           False
# 58315       1.760132e+09           False
# 58316       1.760133e+09           False
# 58317       1.760133e+09           False
# 58318       1.760133e+09           False
#
# [5 rows x 23 columns]

# %% [markdown]
# Outputting the original, non-modified dataset in csv format (og_data.csv)

# %%
def export_to_csv(df, output_csv):
    Path(output_csv).parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(output_csv, index=False)
    print(f"Wrote {len(df):,} rows to {output_csv}")

# %%
export_to_csv(merged, OG_CSV)
# Out:
# Wrote 58,319 rows to data/og_data.csv

# %% [markdown]
# Checking the structure of the dataset I've obtained:

# %%
def summary_func(df):
    summary = pd.DataFrame({
        "dtype": df.dtypes,
        "non_null": df.notna().sum(),
        "nulls": df.isna().sum(),
    })
    summary["pct_null"] = summary["nulls"] / len(df)
    summary["nunique_dropna"] = df.nunique(dropna=True)
    summary["nunique_incl_na"] = df.nunique(dropna=False)
    summary = summary.sort_values(["nunique_incl_na","pct_null","dtype"]).reset_index().rename(columns={"index":"column"})
    return summary

# %%
summary_func(merged).head(23)
# Out:
#                                column    dtype  non_null  nulls  pct_null  \
# 0                     audiobook_title   object         0  58319  1.000000
# 1                       audiobook_uri   object         0  58319  1.000000
# 2               audiobook_chapter_uri   object         0  58319  1.000000
# 3             audiobook_chapter_title   object         0  58319  1.000000
# 4                             shuffle     bool     58319      0  0.000000
# 5                             skipped     bool     58319      0  0.000000
# 6                             offline     bool     58319      0  0.000000
# 7                      incognito_mode     bool     58319      0  0.000000
# 8                            platform   object     58319      0  0.000000
# 9                        reason_start   object     58319      0  0.000000
# 10                         reason_end   object     58319      0  0.000000
# 11                       conn_country   object     58319      0  0.000000
# 12                  episode_show_name   object        22  58297  0.999623
# 13                       episode_name   object        22  58297  0.999623
# 14                spotify_episode_uri   object        22  58297  0.999623
# 15                            ip_addr   object     58319      0  0.000000
# 16  master_metadata_album_artist_name   object     58297     22  0.000377
# 17   master_metadata_album_album_name   object     58297     22  0.000377
# 18         master_metadata_track_name   object     58297     22  0.000377
# 19                  spotify_track_uri   object     58297     22  0.000377
# 20                          ms_played    int64     58319      0  0.000000
# 21                  offline_timestamp  float64     46098  12221  0.209554
# 22                                 ts   object     58319      0  0.000000
#
#     nunique_dropna  nunique_incl_na
# 0                0                1
# 1                0                1
# 2                0                1
# 3                0                1
# 4                2                2
# 5                2                2
# 6                2                2
# 7                2                2
# 8                7                7
# 9                9                9
# 10              10               10
# 11              14               14
# 12              15               16
# 13              18               19
# 14              18               19
# 15            1120             1120
# 16            5406             5407
# 17            9497             9498
# 18           12100            12101
# 19           14074            14075
# 20           22361            22361
# 21           44450            44451
# 22           56086            56086

# %% [markdown]
# I noticed that there are columns which in my case might be empty or have too few non-null values (for example, I usually don't listen to audiobooks or podcasts on Spotify, so all of the rows and columns related to those topics have to be removed). I also remove the ip address and incognito mode columns for data privacy purposes.

# %%
music_only = merged[merged["spotify_track_uri"].notna()].reset_index(drop=True)

# %%
drop_cols = ["episode_show_name", "episode_name", "spotify_episode_uri", "audiobook_title", "audiobook_uri", "audiobook_chapter_uri", "audiobook_chapter_title", "ip_addr", "incognito_mode", "offline_timestamp", "shuffle"]
music_only = music_only.drop(columns=drop_cols)
music_only.shape
# Out:
# (58297, 12)

# %%
summary_func(music_only).head(14)
# Out:
#                                column   dtype  non_null  nulls  pct_null  \
# 0                             skipped    bool     58297      0       0.0
# 1                             offline    bool     58297      0       0.0
# 2                            platform  object     58297      0       0.0
# 3                        reason_start  object     58297      0       0.0
# 4                          reason_end  object     58297      0       0.0
# 5                        conn_country  object     58297      0       0.0
# 6   master_metadata_album_artist_name  object     58297      0       0.0
# 7    master_metadata_album_album_name  object     58297      0       0.0
# 8          master_metadata_track_name  object     58297      0       0.0
# 9                   spotify_track_uri  object     58297      0       0.0
# 10                          ms_played   int64     58297      0       0.0
# 11                                 ts  object     58297      0       0.0
#
#     nunique_dropna  nunique_incl_na
# 0                2                2
# 1                2                2
# 2                7                7
# 3                9                9
# 4               10               10
# 5               14               14
# 6             5406             5406
# 7             9497             9497
# 8            12100            12100
# 9            14074            14074
# 10           22342            22342
# 11           56064            56064

# %%
music_only.head()
# Out:
#                      ts platform  ms_played conn_country  \
# 0  2022-12-23T14:38:28Z  android     155986           UA
# 1  2022-12-23T14:40:52Z  android     143272           UA
# 2  2022-12-23T14:43:57Z  android     184508           UA
# 3  2022-12-23T14:44:08Z  android       1280           UA
# 4  2022-12-23T14:46:01Z  android     113265           UA
#
#                master_metadata_track_name master_metadata_album_artist_name  \
# 0                              The Fusion                             Omnia
# 1                                 Absolut                         Bjornberg
# 2                          Rio De Janeiro                   Maison & Dragen
# 3                       J'ai Envie De Toi                              GAIA
# 4  Let It Snow! Let It Snow! Let It Snow!                   Olivier Abeille
#
#   master_metadata_album_album_name                     spotify_track_uri  \
# 0  A State Of Trance Year Mix 2012  spotify:track:6Rd4QKdxu1mxigZrL3f2Go
# 1                          Absolut  spotify:track:7jBLucQFTopT38PDxm0s0V
# 2               EDM Experience 001  spotify:track:7c7WEErzg7TWLUUY8llgEs
# 3                J'ai Envie De Toi  spotify:track:3bupH9r8ZlCeLGMvlyL7rE
# 4                    Xmas Memories  spotify:track:6EHw6eo7BwCiBDUro7YNdp
#
#   reason_start reason_end  skipped  offline
# 0    trackdone  trackdone    False    False
# 1    trackdone  trackdone    False    False
# 2    trackdone  trackdone    False    False
# 3    trackdone    endplay     True    False
# 4     clickrow  trackdone    False    False

# %%
export_to_csv(music_only, CLEANED_CSV)
# Out:
# Wrote 58,297 rows to data/cleaned_data.csv

# %% [markdown]
# I like the data I've got, but to do more discoveries about my music taste and habits, I'd like to enrich it with additional info about artists. For that, I will use Spotify API:

# %% [markdown]
# I see that now I don't have the artist URI column in my dataset, but it is crucial for fetching additional data about the artists. So I'll use Spotify API and track URIs:

# %%
CLIENT_ID = '416eb70cbfc84c79a0626aa40568d86a'
CLIENT_SECRET = 'here_goes_my_secret'

def get_spotify_token(client_id: str, client_secret: str) -> str:
    """Get Spotify API access token"""
    auth_url = 'https://accounts.spotify.com/api/token'
    auth_response = requests.post(auth_url, {
        'grant_type': 'client_credentials',
        'client_id': client_id,
        'client_secret': client_secret,
    })
    auth_response.raise_for_status()
    return auth_response.json()['access_token']

token = get_spotify_token(CLIENT_ID, CLIENT_SECRET)
print("✓ Successfully connected to Spotify API!")
# Out:
# ✓ Successfully connected to Spotify API!

# %% [markdown]
# As Spotify has limits on the amount of requests I can send, in order to minimize it I will firsty get the unique track IDs and artists I have been listening to:

# %%
def extract_track_id(spotify_uri):
    """Extract track ID from spotify:track:XXXXX format"""
    if pd.isna(spotify_uri) or not isinstance(spotify_uri, str):
        return None
    parts = spotify_uri.split(':')
    if len(parts) == 3 and parts[0] == 'spotify' and parts[1] == 'track':
        return parts[2]
    return None

music_only['track_id'] = music_only['spotify_track_uri'].apply(extract_track_id)

unique_tracks = music_only[music_only['track_id'].notna()]['track_id'].unique()

print(f"Total rows: {len(music_only):,}")
print(f"Unique tracks: {len(unique_tracks):,}")
print(f"Reduction: {len(music_only) - len(unique_tracks):,} duplicate track plays")
print(f"\nEstimated API calls needed: ~{len(unique_tracks) // 50 + 1} for tracks") #50 artists can be processed per API call
# Out:
# Total rows: 58,297
# Unique tracks: 14,074
# Reduction: 44,223 duplicate track plays
#
# Estimated API calls needed: ~282 for tracks

# %%
def get_tracks_batch(track_ids, token):
    """Get multiple tracks in a single API call (up to 50)"""
    headers = {'Authorization': f'Bearer {token}'}
    track_ids_str = ','.join(track_ids[:50])
    url = f'https://api.spotify.com/v1/tracks?ids={track_ids_str}'
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return response.json()

#to store track_id -> artist_id mapping
track_to_artist = {}

batch_size = 50
total_batches = len(unique_tracks) // batch_size + 1

print(f"Fetching track data in {total_batches} batches...")
print("This will take approximately {:.1f} minutes".format(total_batches * 0.05 / 60))

for i in range(0, len(unique_tracks), batch_size):
    batch = unique_tracks[i:i+batch_size].tolist()
    
    try:
        result = get_tracks_batch(batch, token)
        
        for track in result.get('tracks', []):
            if track and track.get('artists'):
                track_id = track['id']
                artist_id = track['artists'][0]['id']
                artist_name = track['artists'][0]['name']
                
                track_to_artist[track_id] = {
                    'artist_id': artist_id,
                    'artist_name': artist_name
                }
        
        if (i // batch_size + 1) % 10 == 0:
            print(f"Progress: {i + batch_size}/{len(unique_tracks)} tracks processed")
        
        time.sleep(0.05)
        
    except Exception as e:
        print(f"Error in batch {i//batch_size + 1}: {e}")
        time.sleep(1)

print(f"\n✓ Fetched data for {len(track_to_artist):,} tracks")

with open('track_to_artist_mapping.json', 'w') as f:
    json.dump(track_to_artist, f)
print("✓ Saved intermediate mapping to 'track_to_artist_mapping.json'")
# Out:
# Fetching track data in 282 batches...
# This will take approximately 0.2 minutes
# Progress: 500/14074 tracks processed
# Progress: 1000/14074 tracks processed
# Progress: 1500/14074 tracks processed
# Progress: 2000/14074 tracks processed
# Progress: 2500/14074 tracks processed
# Progress: 3000/14074 tracks processed
# Progress: 3500/14074 tracks processed
# Progress: 4000/14074 tracks processed
# Progress: 4500/14074 tracks processed
# Progress: 5000/14074 tracks processed
# Progress: 5500/14074 tracks processed
# Progress: 6000/14074 tracks processed
# Progress: 6500/14074 tracks processed
# Progress: 7000/14074 tracks processed
# Progress: 7500/14074 tracks processed
# Progress: 8000/14074 tracks processed
# Progress: 8500/14074 tracks processed
# Progress: 9000/14074 tracks processed
# Progress: 9500/14074 tracks processed
# Progress: 10000/14074 tracks processed
# Progress: 10500/14074 tracks processed
# Progress: 11000/14074 tracks processed
# Progress: 11500/14074 tracks processed
# Progress: 12000/14074 tracks processed
# Progress: 12500/14074 tracks processed
# Progress: 13000/14074 tracks processed
# Progress: 13500/14074 tracks processed
# Progress: 14000/14074 tracks processed
#
# ✓ Fetched data for 14,074 tracks
# ✓ Saved intermediate mapping to 'track_to_artist_mapping.json'

# %%
#get unique artists
unique_artist_ids = set()
unique_artist_names = set()

for track_data in track_to_artist.values():
    unique_artist_ids.add(track_data['artist_id'])
    unique_artist_names.add(track_data['artist_name'])

print(f"Unique tracks: {len(unique_tracks):,}")
print(f"Unique artists: {len(unique_artist_ids):,}")
print(f"Reduction: {len(unique_tracks) - len(unique_artist_ids):,} repeated artists")
print(f"\nEstimated API calls needed for artists: {len(unique_artist_ids):,}")
print(f"Estimated time: ~{len(unique_artist_ids) * 0.05 / 60:.1f} minutes")
# Out:
# Unique tracks: 14,074
# Unique artists: 5,406
# Reduction: 8,668 repeated artists
#
# Estimated API calls needed for artists: 5,406
# Estimated time: ~4.5 minutes

# %%
def get_artists_batch(artist_ids, token, max_retries=5):
    """
    Get multiple artists in a single API call (up to 50)
    With exponential backoff for rate limiting
    """
    headers = {'Authorization': f'Bearer {token}'}
    artist_ids_str = ','.join(artist_ids[:50])
    url = f'https://api.spotify.com/v1/artists?ids={artist_ids_str}'
    
    for attempt in range(max_retries):
        try:
            response = requests.get(url, headers=headers)
            
            if response.status_code == 429:
                retry_after = int(response.headers.get('Retry-After', 5))
                print(f"  ⚠ Rate limited. Waiting {retry_after} seconds...")
                time.sleep(retry_after + 1)
                continue
            
            response.raise_for_status()
            return response.json()
            
        except requests.exceptions.RequestException as e:
            if attempt < max_retries - 1:
                wait_time = 2 ** attempt  #exponential backoff: 1, 2, 4, 8, 16 seconds
                print(f"  ⚠ Error (attempt {attempt + 1}/{max_retries}): {e}")
                print(f"  Waiting {wait_time} seconds before retry...")
                time.sleep(wait_time)
            else:
                print(f"  ✗ Failed after {max_retries} attempts: {e}")
                return None
    
    return None

try:
    with open('artist_data.json', 'r') as f:
        artist_data = json.load(f)
    print(f"Loaded existing cache with {len(artist_data)} artists")
except FileNotFoundError:
    artist_data = {}
    print("No existing cache found, starting fresh")

unique_artists_list = list(unique_artist_ids)
total_artists = len(unique_artists_list)

artists_to_fetch = [aid for aid in unique_artists_list if aid not in artist_data]

print(f"\nTotal unique artists: {total_artists:,}")
print(f"Already cached: {len(artist_data):,}")
print(f"To fetch: {len(artists_to_fetch):,}")

batch_size = 50
total_batches = len(artists_to_fetch) // batch_size + (1 if len(artists_to_fetch) % batch_size else 0)

print(f"Batches needed: {total_batches}")
print(f"Estimated time: ~{total_batches * 0.5 / 60:.1f} minutes\n")

#process in batches
for i in range(0, len(artists_to_fetch), batch_size):
    batch = artists_to_fetch[i:i+batch_size]
    batch_num = i // batch_size + 1
    
    print(f"Batch {batch_num}/{total_batches}: Fetching {len(batch)} artists...")
    
    result = get_artists_batch(batch, token)
    
    if result and result.get('artists'):
        for artist in result['artists']:
            if artist:  # artist can be None if not found
                artist_data[artist['id']] = {
                    'name': artist.get('name'),
                    'genres': ', '.join(artist.get('genres', [])[:5]),
                    'popularity': artist.get('popularity'),
                    'followers': artist.get('followers', {}).get('total'),
                }
        
        print(f"  ✓ Batch {batch_num} complete ({len(artist_data)}/{total_artists} total)")
    else:
        print(f"  ✗ Batch {batch_num} failed")
        #add empty entries for failed artists to avoid re-fetching
        for artist_id in batch:
            if artist_id not in artist_data:
                artist_data[artist_id] = {
                    'name': None,
                    'genres': None,
                    'popularity': None,
                    'followers': None,
                }
    
    if batch_num % 5 == 0:
        with open('artist_data.json', 'w') as f:
            json.dump(artist_data, f)
        print(f"  💾 Progress saved")
    
    time.sleep(0.5)

with open('artist_data.json', 'w') as f:
    json.dump(artist_data, f)

print(f"\n✓ Fetched data for {len(artist_data):,} artists")
print(f"✓ Saved artist data to 'artist_data.json'")
# Out:
# No existing cache found, starting fresh
#
# Total unique artists: 5,406
# Already cached: 0
# To fetch: 5,406
# Batches needed: 109
# Estimated time: ~0.9 minutes
#
# Batch 1/109: Fetching 50 artists...
#   ✓ Batch 1 complete (50/5406 total)
# Batch 2/109: Fetching 50 artists...
#   ✓ Batch 2 complete (100/5406 total)
# Batch 3/109: Fetching 50 artists...
#   ✓ Batch 3 complete (150/5406 total)
# Batch 4/109: Fetching 50 artists...
#   ✓ Batch 4 complete (200/5406 total)
# Batch 5/109: Fetching 50 artists...
#   ✓ Batch 5 complete (250/5406 total)
#   💾 Progress saved
# Batch 6/109: Fetching 50 artists...
#   ✓ Batch 6 complete (300/5406 total)
# Batch 7/109: Fetching 50 artists...
#   ✓ Batch 7 complete (350/5406 total)
# Batch 8/109: Fetching 50 artists...
#   ✓ Batch 8 complete (400/5406 total)
# Batch 9/109: Fetching 50 artists...
#   ✓ Batch 9 complete (450/5406 total)
# Batch 10/109: Fetching 50 artists...
#   ✓ Batch 10 complete (500/5406 total)
#   💾 Progress saved
# Batch 11/109: Fetching 50 artists...
#   ✓ Batch 11 complete (550/5406 total)
# Batch 12/109: Fetching 50 artists...
#   ✓ Batch 12 complete (600/5406 total)
# Batch 13/109: Fetching 50 artists...
#   ✓ Batch 13 complete (650/5406 total)
# Batch 14/109: Fetching 50 artists...
#   ✓ Batch 14 complete (700/5406 total)
# Batch 15/109: Fetching 50 artists...
#   ✓ Batch 15 complete (750/5406 total)
#   💾 Progress saved
# Batch 16/109: Fetching 50 artists...
#   ✓ Batch 16 complete (800/5406 total)
# Batch 17/109: Fetching 50 artists...
#   ✓ Batch 17 complete (850/5406 total)
# Batch 18/109: Fetching 50 artists...
#   ✓ Batch 18 complete (900/5406 total)
# Batch 19/109: Fetching 50 artists...
#   ✓ Batch 19 complete (950/5406 total)
# Batch 20/109: Fetching 50 artists...
#   ✓ Batch 20 complete (1000/5406 total)
#   💾 Progress saved
# Batch 21/109: Fetching 50 artists...
#   ✓ Batch 21 complete (1050/5406 total)
# Batch 22/109: Fetching 50 artists...
#   ✓ Batch 22 complete (1100/5406 total)
# Batch 23/109: Fetching 50 artists...
#   ✓ Batch 23 complete (1150/5406 total)
# Batch 24/109: Fetching 50 artists...
#   ✓ Batch 24 complete (1200/5406 total)
# Batch 25/109: Fetching 50 artists...
#   ✓ Batch 25 complete (1250/5406 total)
#   💾 Progress saved
# Batch 26/109: Fetching 50 artists...
#   ✓ Batch 26 complete (1300/5406 total)
# Batch 27/109: Fetching 50 artists...
#   ✓ Batch 27 complete (1350/5406 total)
# Batch 28/109: Fetching 50 artists...
#   ✓ Batch 28 complete (1400/5406 total)
# Batch 29/109: Fetching 50 artists...
#   ✓ Batch 29 complete (1450/5406 total)
# Batch 30/109: Fetching 50 artists...
#   ✓ Batch 30 complete (1500/5406 total)
#   💾 Progress saved
# Batch 31/109: Fetching 50 artists...
#   ✓ Batch 31 complete (1550/5406 total)
# Batch 32/109: Fetching 50 artists...
#   ✓ Batch 32 complete (1600/5406 total)
# Batch 33/109: Fetching 50 artists...
#   ✓ Batch 33 complete (1650/5406 total)
# Batch 34/109: Fetching 50 artists...
#   ✓ Batch 34 complete (1700/5406 total)
# Batch 35/109: Fetching 50 artists...
#   ✓ Batch 35 complete (1750/5406 total)
#   💾 Progress saved
# Batch 36/109: Fetching 50 artists...
#   ✓ Batch 36 complete (1800/5406 total)
# Batch 37/109: Fetching 50 artists...
#   ✓ Batch 37 complete (1850/5406 total)
# Batch 38/109: Fetching 50 artists...
#   ✓ Batch 38 complete (1900/5406 total)
# Batch 39/109: Fetching 50 artists...
#   ✓ Batch 39 complete (1950/5406 total)
# Batch 40/109: Fetching 50 artists...
#   ✓ Batch 40 complete (2000/5406 total)
#   💾 Progress saved
# Batch 41/109: Fetching 50 artists...
#   ✓ Batch 41 complete (2050/5406 total)
# Batch 42/109: Fetching 50 artists...
#   ✓ Batch 42 complete (2100/5406 total)
# Batch 43/109: Fetching 50 artists...
#   ✓ Batch 43 complete (2150/5406 total)
# Batch 44/109: Fetching 50 artists...
#   ✓ Batch 44 complete (2200/5406 total)
# Batch 45/109: Fetching 50 artists...
#   ✓ Batch 45 complete (2250/5406 total)
#   💾 Progress saved
# Batch 46/109: Fetching 50 artists...
#   ✓ Batch 46 complete (2300/5406 total)
# Batch 47/109: Fetching 50 artists...
#   ✓ Batch 47 complete (2350/5406 total)
# Batch 48/109: Fetching 50 artists...
#   ✓ Batch 48 complete (2400/5406 total)
# Batch 49/109: Fetching 50 artists...
#   ✓ Batch 49 complete (2450/5406 total)
# Batch 50/109: Fetching 50 artists...
#   ✓ Batch 50 complete (2500/5406 total)
#   💾 Progress saved
# Batch 51/109: Fetching 50 artists...
#   ✓ Batch 51 complete (2550/5406 total)
# Batch 52/109: Fetching 50 artists...
#   ✓ Batch 52 complete (2600/5406 total)
# Batch 53/109: Fetching 50 artists...
#   ✓ Batch 53 complete (2650/5406 total)
# Batch 54/109: Fetching 50 artists...
#   ✓ Batch 54 complete (2700/5406 total)
# Batch 55/109: Fetching 50 artists...
#   ✓ Batch 55 complete (2750/5406 total)
#   💾 Progress saved
# Batch 56/109: Fetching 50 artists...
#   ✓ Batch 56 complete (2800/5406 total)
# Batch 57/109: Fetching 50 artists...
#   ✓ Batch 57 complete (2850/5406 total)
# Batch 58/109: Fetching 50 artists...
#   ✓ Batch 58 complete (2900/5406 total)
# Batch 59/109: Fetching 50 artists...
#   ✓ Batch 59 complete (2950/5406 total)
# Batch 60/109: Fetching 50 artists...
#   ✓ Batch 60 complete (3000/5406 total)
#   💾 Progress saved
# Batch 61/109: Fetching 50 artists...
#   ✓ Batch 61 complete (3050/5406 total)
# Batch 62/109: Fetching 50 artists...
#   ✓ Batch 62 complete (3100/5406 total)
# Batch 63/109: Fetching 50 artists...
#   ✓ Batch 63 complete (3150/5406 total)
# Batch 64/109: Fetching 50 artists...
#   ✓ Batch 64 complete (3200/5406 total)
# Batch 65/109: Fetching 50 artists...
#   ✓ Batch 65 complete (3250/5406 total)
#   💾 Progress saved
# Batch 66/109: Fetching 50 artists...
#   ✓ Batch 66 complete (3300/5406 total)
# Batch 67/109: Fetching 50 artists...
#   ✓ Batch 67 complete (3350/5406 total)
# Batch 68/109: Fetching 50 artists...
#   ✓ Batch 68 complete (3400/5406 total)
# Batch 69/109: Fetching 50 artists...
#   ✓ Batch 69 complete (3450/5406 total)
# Batch 70/109: Fetching 50 artists...
#   ✓ Batch 70 complete (3500/5406 total)
#   💾 Progress saved
# Batch 71/109: Fetching 50 artists...
#   ✓ Batch 71 complete (3550/5406 total)
# Batch 72/109: Fetching 50 artists...
#   ✓ Batch 72 complete (3600/5406 total)
# Batch 73/109: Fetching 50 artists...
#   ✓ Batch 73 complete (3650/5406 total)
# Batch 74/109: Fetching 50 artists...
#   ✓ Batch 74 complete (3700/5406 total)
# Batch 75/109: Fetching 50 artists...
#   ✓ Batch 75 complete (3750/5406 total)
#   💾 Progress saved
# Batch 76/109: Fetching 50 artists...
#   ✓ Batch 76 complete (3800/5406 total)
# Batch 77/109: Fetching 50 artists...
#   ✓ Batch 77 complete (3850/5406 total)
# Batch 78/109: Fetching 50 artists...
#   ✓ Batch 78 complete (3900/5406 total)
# Batch 79/109: Fetching 50 artists...
#   ✓ Batch 79 complete (3950/5406 total)
# Batch 80/109: Fetching 50 artists...
#   ✓ Batch 80 complete (4000/5406 total)
#   💾 Progress saved
# Batch 81/109: Fetching 50 artists...
#   ✓ Batch 81 complete (4050/5406 total)
# Batch 82/109: Fetching 50 artists...
#   ✓ Batch 82 complete (4100/5406 total)
# Batch 83/109: Fetching 50 artists...
#   ✓ Batch 83 complete (4150/5406 total)
# Batch 84/109: Fetching 50 artists...
#   ✓ Batch 84 complete (4200/5406 total)
# Batch 85/109: Fetching 50 artists...
#   ✓ Batch 85 complete (4250/5406 total)
#   💾 Progress saved
# Batch 86/109: Fetching 50 artists...
#   ✓ Batch 86 complete (4300/5406 total)
# Batch 87/109: Fetching 50 artists...
#   ✓ Batch 87 complete (4350/5406 total)
# Batch 88/109: Fetching 50 artists...
#   ✓ Batch 88 complete (4400/5406 total)
# Batch 89/109: Fetching 50 artists...
#   ✓ Batch 89 complete (4450/5406 total)
# Batch 90/109: Fetching 50 artists...
#   ✓ Batch 90 complete (4500/5406 total)
#   💾 Progress saved
# Batch 91/109: Fetching 50 artists...
#   ✓ Batch 91 complete (4550/5406 total)
# Batch 92/109: Fetching 50 artists...
#   ✓ Batch 92 complete (4600/5406 total)
# Batch 93/109: Fetching 50 artists...
#   ✓ Batch 93 complete (4650/5406 total)
# Batch 94/109: Fetching 50 artists...
#   ✓ Batch 94 complete (4700/5406 total)
# Batch 95/109: Fetching 50 artists...
#   ✓ Batch 95 complete (4750/5406 total)
#   💾 Progress saved
# Batch 96/109: Fetching 50 artists...
#   ✓ Batch 96 complete (4800/5406 total)
# Batch 97/109: Fetching 50 artists...
#   ✓ Batch 97 complete (4850/5406 total)
# Batch 98/109: Fetching 50 artists...
#   ✓ Batch 98 complete (4900/5406 total)
# Batch 99/109: Fetching 50 artists...
#   ✓ Batch 99 complete (4950/5406 total)
# Batch 100/109: Fetching 50 artists...
#   ✓ Batch 100 complete (5000/5406 total)
#   💾 Progress saved
# Batch 101/109: Fetching 50 artists...
#   ✓ Batch 101 complete (5050/5406 total)
# Batch 102/109: Fetching 50 artists...
#   ✓ Batch 102 complete (5100/5406 total)
# Batch 103/109: Fetching 50 artists...
#   ✓ Batch 103 complete (5150/5406 total)
# Batch 104/109: Fetching 50 artists...
#   ✓ Batch 104 complete (5200/5406 total)
# Batch 105/109: Fetching 50 artists...
#   ✓ Batch 105 complete (5250/5406 total)
#   💾 Progress saved
# Batch 106/109: Fetching 50 artists...
#   ✓ Batch 106 complete (5300/5406 total)
# Batch 107/109: Fetching 50 artists...
#   ✓ Batch 107 complete (5350/5406 total)
# Batch 108/109: Fetching 50 artists...
#   ✓ Batch 108 complete (5400/5406 total)
# Batch 109/109: Fetching 6 artists...
#   ✓ Batch 109 complete (5406/5406 total)
#
# ✓ Fetched data for 5,406 artists
# ✓ Saved artist data to 'artist_data.json'

# %%
print("Mapping artist data back to original dataframe...")
music_only['artist_id'] = None
music_only['artist_name_spotify'] = None
music_only['artist_genres'] = None
music_only['artist_popularity'] = None
music_only['artist_followers'] = None

#map using track_id
for idx, row in music_only.iterrows():
    track_id = row['track_id']
    
    if pd.notna(track_id) and track_id in track_to_artist:
        artist_id = track_to_artist[track_id]['artist_id']
        
        music_only.at[idx, 'artist_id'] = artist_id
        
        if artist_id in artist_data:
            music_only.at[idx, 'artist_name_spotify'] = artist_data[artist_id]['name']
            music_only.at[idx, 'artist_genres'] = artist_data[artist_id]['genres']
            music_only.at[idx, 'artist_popularity'] = artist_data[artist_id]['popularity']
            music_only.at[idx, 'artist_followers'] = artist_data[artist_id]['followers']
    
    if (idx + 1) % 5000 == 0:
        print(f"Mapped {idx + 1}/{len(music_only)} rows")

print("\n✓ Mapping complete!")
print(f"Rows with artist data: {music_only['artist_id'].notna().sum():,}")
# Out:
# Mapping artist data back to original dataframe...
# Mapped 5000/58297 rows
# Mapped 10000/58297 rows
# Mapped 15000/58297 rows
# Mapped 20000/58297 rows
# Mapped 25000/58297 rows
# Mapped 30000/58297 rows
# Mapped 35000/58297 rows
# Mapped 40000/58297 rows
# Mapped 45000/58297 rows
# Mapped 50000/58297 rows
# Mapped 55000/58297 rows
#
# ✓ Mapping complete!
# Rows with artist data: 58,297

# %%
music_only
# Out:
#                          ts platform  ms_played conn_country  \
# 0      2022-12-23T14:38:28Z  android     155986           UA
# 1      2022-12-23T14:40:52Z  android     143272           UA
# 2      2022-12-23T14:43:57Z  android     184508           UA
# 3      2022-12-23T14:44:08Z  android       1280           UA
# 4      2022-12-23T14:46:01Z  android     113265           UA
# ...                     ...      ...        ...          ...
# 58292  2025-10-10T21:40:06Z  android     215813           FR
# 58293  2025-10-10T21:43:10Z  android     184013           FR
# 58294  2025-10-10T21:47:45Z  android     273765           FR
# 58295  2025-10-10T21:51:27Z  android     221273           FR
# 58296  2025-10-10T21:53:46Z  android     139384           FR
#
#                    master_metadata_track_name  \
# 0                                  The Fusion
# 1                                     Absolut
# 2                              Rio De Janeiro
# 3                           J'ai Envie De Toi
# 4      Let It Snow! Let It Snow! Let It Snow!
# ...                                       ...
# 58292                           Gonna Love Ya
# 58293                                Chemical
# 58294                   Virus (How About Now)
# 58295                     Reload - Radio Edit
# 58296                Gatluak - Bakermat Remix
#
#       master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                                 Omnia  A State Of Trance Year Mix 2012
# 1                             Bjornberg                          Absolut
# 2                       Maison & Dragen               EDM Experience 001
# 3                                  GAIA                J'ai Envie De Toi
# 4                       Olivier Abeille                    Xmas Memories
# ...                                 ...                              ...
# 58292                            Avicii                          Stories
# 58293                       Post Malone                         Chemical
# 58294                     Martin Garrix            Virus (How About Now)
# 58295                Sebastian Ingrosso                           Reload
# 58296                            Kronan                          Gatluak
#
#                           spotify_track_uri reason_start reason_end  skipped  \
# 0      spotify:track:6Rd4QKdxu1mxigZrL3f2Go    trackdone  trackdone    False
# 1      spotify:track:7jBLucQFTopT38PDxm0s0V    trackdone  trackdone    False
# 2      spotify:track:7c7WEErzg7TWLUUY8llgEs    trackdone  trackdone    False
# 3      spotify:track:3bupH9r8ZlCeLGMvlyL7rE    trackdone    endplay     True
# 4      spotify:track:6EHw6eo7BwCiBDUro7YNdp     clickrow  trackdone    False
# ...                                     ...          ...        ...      ...
# 58292  spotify:track:1rDETmcizen79JghAEm1Se    trackdone  trackdone    False
# 58293  spotify:track:5w40ZYhbBMAlHYNDaVJIUu    trackdone  trackdone    False
# 58294  spotify:track:3ukWpmRHvpuDATCJkgLEkF    trackdone  trackdone    False
# 58295  spotify:track:5jyUBKpmaH670zrXrE0wmO    trackdone  trackdone    False
# 58296  spotify:track:0GT2hQQ6mdHeW0AZDl5NlJ    trackdone  trackdone    False
#
#        offline                track_id               artist_id  \
# 0        False  6Rd4QKdxu1mxigZrL3f2Go  0XZkeCAlpiO5qcIlAJzZaA
# 1        False  7jBLucQFTopT38PDxm0s0V  2UvXv8S4pzzh6ze3ztLIRh
# 2        False  7c7WEErzg7TWLUUY8llgEs  07JTRGL3SO0v492XOpYhGN
# 3        False  3bupH9r8ZlCeLGMvlyL7rE  3Jkc5q9qBSNOTf3IvAyJW9
# 4        False  6EHw6eo7BwCiBDUro7YNdp  43d1D4ncfmUYZCkZsxvfEy
# ...        ...                     ...                     ...
# 58292    False  1rDETmcizen79JghAEm1Se  1vCWHaC5f2uS3yhpwWbIA6
# 58293    False  5w40ZYhbBMAlHYNDaVJIUu  246dkjvS1zLTtiykXe5h60
# 58294    False  3ukWpmRHvpuDATCJkgLEkF  60d24wfXkVzDSfLS6hyCjZ
# 58295    False  5jyUBKpmaH670zrXrE0wmO  6hyMWrxGBsOx6sWcVj1DqP
# 58296    False  0GT2hQQ6mdHeW0AZDl5NlJ  6AC7fqQQgNwXXpBa5bqyBr
#
#       artist_name_spotify                        artist_genres  \
# 0                   Omnia           trance, progressive trance
# 1               Bjornberg
# 2         Maison & Dragen
# 3                    GAIA           trance, progressive trance
# 4         Olivier Abeille                                lo-fi
# ...                   ...                                  ...
# 58292              Avicii                                  edm
# 58293         Post Malone
# 58294       Martin Garrix  edm, electronica, progressive house
# 58295  Sebastian Ingrosso                                  edm
# 58296              Kronan
#
#       artist_popularity artist_followers
# 0                    39            48581
# 1                    11             2719
# 2                    18             5861
# 3                    45           108662
# 4                    14              437
# ...                 ...              ...
# 58292                78         23420376
# 58293                86         47656151
# 58294                74         15121775
# 58295                67          1007675
# 58296                48            13664
#
# [58297 rows x 18 columns]

# %%
(music_only['master_metadata_album_artist_name'] == music_only['artist_name_spotify']).all()
# Out:
# False

# %%
(music_only['master_metadata_album_artist_name'] != music_only['artist_name_spotify']).sum()
# Out:
# 257

# %%
music_only[music_only['master_metadata_album_artist_name'] != music_only['artist_name_spotify']]
# Out:
#                          ts platform  ms_played conn_country  \
# 185    2022-12-28T08:40:29Z  android          0           UA
# 560    2023-01-01T02:03:23Z  windows     240298           UA
# 713    2023-01-04T02:30:52Z  windows     110314           UA
# 744    2023-01-05T20:44:11Z  windows      85266           UA
# 2239   2023-02-05T22:31:24Z  windows      90770           UA
# ...                     ...      ...        ...          ...
# 56103  2025-07-05T23:24:39Z  android     228720           BE
# 56138  2025-07-06T01:36:14Z  android     213374           BE
# 56139  2025-07-06T01:40:27Z  android     251874           BE
# 56668  2025-08-05T22:21:14Z  android        546           BE
# 56670  2025-08-05T22:21:24Z  android       7290           BE
#
#              master_metadata_track_name master_metadata_album_artist_name  \
# 185                       Keep Me Close                  Jeffrey Sutorius
# 560                               Стань                          Antytila
# 713    Can't Hold Us (feat. Ray Dalton)           Macklemore & Ryan Lewis
# 744                  Carol of the Bells      Mykola Dmytrovych Leontovych
# 2239                       Never Forget                             Jónsi
# ...                                 ...                               ...
# 56103                       Така, як ти              Svyatoslav Vakarchuk
# 56138                              Tdme                          Antytila
# 56139                   Люди як кораблі                          Antytila
# 56668                            Madame                             blond
# 56670                            Madame                             blond
#
#                         master_metadata_album_album_name  \
# 185                                        Keep Me Close
# 560                                                 MLNL
# 713                                            The Heist
# 744    Home Alone (Original Motion Picture Soundtrack...
# 2239                                      In the Silence
# ...                                                  ...
# 56103                                              Вночі
# 56138                                              Hello
# 56139                                              Сонце
# 56668                                Pour la vie entière
# 56670                                Pour la vie entière
#
#                           spotify_track_uri reason_start reason_end  skipped  \
# 185    spotify:track:6GifPmBMc0n2Gs3zfRkB5D       fwdbtn     fwdbtn     True
# 560    spotify:track:2eRMKybvQJYHBZdbEKKDtz       fwdbtn  trackdone    False
# 713    spotify:track:22skzmqfdWrjJylampe0kt    trackdone     logout    False
# 744    spotify:track:4tHqQMWSqmL6YjXwsqthDI    trackdone  trackdone    False
# 2239   spotify:track:40sYYZZN8BLWs8Qmwamngw      playbtn    endplay     True
# ...                                     ...          ...        ...      ...
# 56103  spotify:track:1hsANSvcIkut1BRVIHXtLO    trackdone  trackdone    False
# 56138  spotify:track:2Pa6q36FP2oAM5q1hFjVSG    trackdone  trackdone    False
# 56139  spotify:track:6iXggLYvLeiccxZq61pl2i    trackdone  trackdone    False
# 56668  spotify:track:0Slo6AUP4sR8gE1wdQBiRM      unknown    endplay     True
# 56670  spotify:track:0Slo6AUP4sR8gE1wdQBiRM      unknown    endplay     True
#
#        offline                track_id               artist_id  \
# 185      False  6GifPmBMc0n2Gs3zfRkB5D  2XGg454n1pSdgoqrfcSDbq
# 560      False  2eRMKybvQJYHBZdbEKKDtz  5sc9td6C7xxPa3mOmmvXPu
# 713      False  22skzmqfdWrjJylampe0kt  3JhNCzhSMTxs9WLGJJxWOY
# 744      False  4tHqQMWSqmL6YjXwsqthDI  3dRfiJ2650SZu6GbydcHNb
# 2239     False  40sYYZZN8BLWs8Qmwamngw  1WCD4cddyV9Yk4zk7H9eju
# ...        ...                     ...                     ...
# 56103    False  1hsANSvcIkut1BRVIHXtLO  2xEuSZSodyOIuUAxBM3I5I
# 56138    False  2Pa6q36FP2oAM5q1hFjVSG  5sc9td6C7xxPa3mOmmvXPu
# 56139    False  6iXggLYvLeiccxZq61pl2i  5sc9td6C7xxPa3mOmmvXPu
# 56668    False  0Slo6AUP4sR8gE1wdQBiRM  6bAfbEF8yCMBTtXEBFLh2x
# 56670    False  0Slo6AUP4sR8gE1wdQBiRM  6bAfbEF8yCMBTtXEBFLh2x
#
#         artist_name_spotify                 artist_genres artist_popularity  \
# 185        JEFFREY SUTORIUS   progressive house, big room                28
# 560                АНТИТІЛА                                              42
# 713              Macklemore                                              74
# 744           John Williams                    soundtrack                69
# 2239           Greta Salóme                                              13
# ...                     ...                           ...               ...
# 56103  Sviatoslav Vakarchuk                                              40
# 56138              АНТИТІЛА                                              42
# 56139              АНТИТІЛА                                              42
# 56668                 Blond  french indie pop, french pop                28
# 56670                 Blond  french indie pop, french pop                28
#
#       artist_followers
# 185              17774
# 560             392136
# 713            2814815
# 744            1598950
# 2239              3771
# ...                ...
# 56103            78198
# 56138           392136
# 56139           392136
# 56668             5646
# 56670             5646
#
# [257 rows x 18 columns]

# %%
music_only = music_only.drop(columns='artist_name_spotify')

# %%
export_to_csv(music_only, ENRICHED_CSV)
# Out:
# Wrote 58,297 rows to data/music_data.csv
